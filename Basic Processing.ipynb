# %% [markdown]
# Start here to process images from CZI to background subtraction before moving onto analyses

# %%
folder_path = '/Users/allisonpickle/Desktop/251120_NoraLPSPlate'
print(folder_path)

# %%
from Basic_Processing import *

# %% [markdown]
# Rename CZIs in each subfolder to the enclosing folders' name with a numerical iteration. Must have images in subfolders to work.

# %%
# Rename_and_Copy_CZIs(folder_path)
rename_and_copy_czi_files(folder_path)
folder_path = folder_path + '/All'
print(folder_path)

# %% [markdown]
# Split CZI into its channels:

# %%
Split_CZI_Channels(folder_path)

# %% [markdown]
# Convert to 8-bit image:

# %%
Convert_to_8bit(folder_path)

# %% [markdown]
# Background Subtraction:
# Code works but highly recommend still running it in FIJI

# %%
# Radius = 50 # 50 is standard
# Background_Subtraction(folder_path, Radius, display=False, save=True)

# %%
# folder_path = folder_path + '/1_Background Subtraction'
# print(folder_path)

# %% [markdown]
# Optimize Contrast if necessary

# %%
Optimize_Contrast(folder_path, display = False, save = True)

# %%
Convert_to_8bit(folder_path)
